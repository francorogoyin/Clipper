# %%
import Tools as t
import pandas as pd
import numpy as np
from notion_client import Client
from datetime import datetime
import re
import emoji
import tkinter as tk
from tkinter import filedialog
from tkinter import simpledialog

# Formularios.
from Formulario import Explorer_Input_Title, Filetypes_Tuples_Input

# P_Start.
import P_Start

# Módulos personalizados.
import sys
sys.path.append('c:/Users/tomas/Documents/Programación/Universidad/Patricionog/Datos/Paquetes/')
import Forpy as fg
import Excpy as ex
import Frampy as fr
import Stringpy as st
import Listpy as ls
import Graphpy as gr
import Notpy as nt
import Highpy as hg

# %%
# Notion.
Token = '***TOKEN_REMOVIDO***'
Notion_Client = Client(auth=Token)

# %%
# Elecciones del usuario.
Database_ID = '129a53d444454d63820814429c4fb691'

# %%
# Archivo de recortes.
File_Path = 'C:/Users/tomas/Documents/Recortes/2024-12-30.txt'

# %%
# df total del recorte.
df = hg.Build_Df_Of_Highlights(File_Path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 # df total del recorte.
# ----> 2 df = hg.Build_Df_Of_Highlights(File_Path)
#
# File ~\Documents\Programación\Github\Patricionog\Modulio\Highpy.py:313, in Build_Df_Of_Highlights(File_Path)
#     310 df = pd.DataFrame(Notes)
#     312 # Hour Format.
# --> 313 df['Hour'] = pd.to_datetime(df['Hour'], format='%H:%M').dt.time
#     315 # 'Date' column.
#     316 df = Frampy.Create_Date_Column(df, Spanish = True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\tools\datetimes.py:1063, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061             result = arg.tz_localize("utc")
#    1062 elif isinstance(arg, ABCSeries):
# -> 1063     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064     if not cache_array.empty:
#    1065         result = arg.map(cache_array)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\tools\datetimes.py:247, in _maybe_cache(arg, format, cache, convert_listlike)
#     245 unique_dates = unique(arg)
#     246 if len(unique_dates) < len(arg):
# --> 247     cache_dates = convert_listlike(unique_dates, format)
#     248     # GH#45319
#     249     try:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\tools\datetimes.py:433, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     431 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     432 if format is not None and format != "mixed":
# --> 433     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     435 result, tz_parsed = objects_to_datetime64(
#     436     arg,
#     437     dayfirst=dayfirst,
#    (...)
#     441     allow_object=True,
#     442 )
#     444 if tz_parsed is not None:
#     445     # We can take a shortcut since the datetime64 numpy array
#     446     # is in UTC
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\tools\datetimes.py:467, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     456 def _array_strptime_with_fallback(
#     457     arg,
#     458     name,
#    (...)
#     462     errors: str,
#     463 ) -> Index:
#     464     """
#     465     Call array_strptime, with fallback behavior depending on 'errors'.
#     466     """
# --> 467     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     468     if tz_out is not None:
#     469         unit = np.datetime_data(result.dtype)[0]
#
# File strptime.pyx:501, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:451, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:583, in pandas._libs.tslibs.strptime._parse_with_format()
#
# ValueError: time data "12.026.0" doesn't match format "%H:%M", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
# Base de datos con autores e ID de las páginas en Notion dónde se pegan sus notas.
Base_Matcheos = []

# %%
# Extraer autores del recorte.
Autores = t.Extraer_Datos_Nota(File_Path, 'Ambos')
